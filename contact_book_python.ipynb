# %%
contact={}

def display_contact():
    print("Name\t\tContact Number")
    for key in contact:
        print("{}\t\t{}".format(key,contact.get(key)))
        
while True:
    choice = int(input("1. Add new contact \n 2. Search contact\n 3. Display Contact\n 4. Edit Contact\n 5. Delete Contact\n 6. Exist\n Enter the Choice : "))
    if choice ==1:
        name = input("enter the contact name : ")
        phone =input("enter the mobile number : ")
        contact[name]=phone
    elif choice ==2:
        search_name =input("enter the contact name : ")
        if search_name in contact:
            print(search_name,"'s contact number is ",contact[search_name])
        else:
            print("Name is not found in contact : ")
    elif choice==3:
        if not contact:
            print("empty contact book : ")
        else:
            display_contact()
    elif choice ==4:
        edit_contact = input("Enter the contact to be edited!")
        if edit_contact in contact:
            phone =input("Enter mobile number!")
            contact[edit_contact]=phone
            print("contact updated!")
        else:
            print("Name is not found in contact book!")
    elif choice ==5:
        del_contact=input("Enter the contact to be deleted!")
        if del_contact in contact:
            confirm =input("Do you want to delete this contact! y/n")
            if confirm =='y' or confirm =='Y':
                contact.pop(del_contact)
            display_contact()
        else:
            print("Name is not found in contact book!")
    else:
        break
# Out:
# 1. Add new contact
#  2. Search contact
#  3. Display Contact
#  4. Edit Contact
#  5. Delete Contact
#  6. Exist
#  Enter the Choice1
# enter the contact name : komal
# enter the mobile number : 765656
# 1. Add new contact
#  2. Search contact
#  3. Display Contact
#  4. Edit Contact
#  5. Delete Contact
#  6. Exist
#  Enter the Choice2
# enter the contact name : komal
# komal 's contact number is  765656
# 1. Add new contact
#  2. Search contact
#  3. Display Contact
#  4. Edit Contact
#  5. Delete Contact
#  6. Exist
#  Enter the Choice3
# Name		Contact Number
# komal		765656
# 1. Add new contact
#  2. Search contact
#  3. Display Contact
#  4. Edit Contact
#  5. Delete Contact
#  6. Exist
#  Enter the Choice4
# Enter the contact to be edited!komal
# Enter mobil;e number!657657
# contact updated!
# 1. Add new contact
#  2. Search contact
#  3. Display Contact
#  4. Edit Contact
#  5. Delete Contact
#  6. Exist
#  Enter the Choice3
# Name		Contact Number
# komal		657657
# 1. Add new contact
#  2. Search contact
#  3. Display Contact
#  4. Edit Contact
#  5. Delete Contact
#  6. Exist
#  Enter the Choice5
# Enter the contact to be deleted!komal
# Do you want to delete this contact! y/ny
# Name		Contact Number
# 1. Add new contact
#  2. Search contact
#  3. Display Contact
#  4. Edit Contact
#  5. Delete Contact
#  6. Exist
#  Enter the Choice3
# empty contact book :
